# %% [markdown]
# ## Import Dependencies

# %%
# Install a conda package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install numpy folium
# Out:
# Requirement already satisfied: numpy in /Users/hasansulaeman/anaconda3/lib/python3.6/site-packages (1.13.3)
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/55/e2/7e523df8558b7f4b2ab4c62014fd378ccecce3fdc14c9928b272a88ae4cc/folium-0.7.0-py3-none-any.whl (85kB)
#     100% |████████████████████████████████| 92kB 4.9MB/s ta 0:00:011
# Requirement already satisfied: six in /Users/hasansulaeman/anaconda3/lib/python3.6/site-packages (from folium) (1.11.0)
# Requirement already satisfied: requests in /Users/hasansulaeman/anaconda3/lib/python3.6/site-packages (from folium) (2.19.1)
# Requirement already satisfied: jinja2 in /Users/hasansulaeman/anaconda3/lib/python3.6/site-packages (from folium) (2.9.6)
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/63/36/1c93318e9653f4e414a2e0c3b98fc898b4970e939afeedeee6075dd3b703/branca-0.3.1-py3-none-any.whl
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in /Users/hasansulaeman/anaconda3/lib/python3.6/site-packages (from requests->folium) (1.22)
# Requirement already satisfied: idna<2.8,>=2.5 in /Users/hasansulaeman/anaconda3/lib/python3.6/site-packages (from requests->folium) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hasansulaeman/anaconda3/lib/python3.6/site-packages (from requests->folium) (2018.10.15)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/hasansulaeman/anaconda3/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/hasansulaeman/anaconda3/lib/python3.6/site-packages (from jinja2->folium) (1.0)
# Installing collected packages: branca, folium
# Successfully installed branca-0.3.1 folium-0.7.0

# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql
import folium
from folium import plugins
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pymysql.install_as_MySQLdb()

# %% [markdown]
# ----
#
# ### Extract CSVs into DataFrames

# %%
pokemon_file = "Resources/pokemon-spawns.csv"
pokemon_data_df = pd.read_csv(pokemon_file)
pokemon_data_df = pokemon_data_df[["s2_token", "name", "lat", "lng"]]
pokemon_data_df["id"] = pokemon_data_df.index 
pokemon_data_df.head()
# Out:
#       s2_token     name        lat         lng  id
# 0  8085808cc6d   Weedle  37.793592 -122.408721   0
# 1  8085808b51d   Pidgey  37.794746 -122.406420   1
# 2  8085808b271    Zubat  37.794999 -122.404384   2
# 3  808580f3587   Pidgey  37.795644 -122.407128   3
# 4  808580f4b1d  Poliwag  37.795592 -122.406331   4

# %%
m = folium.Map([37.795644, -87.6298], zoom_start=11)
m

# %%
incidence_count = police_data_df.groupby([['X','Y']]).count()
incidence_count

for nam in new_poke_df[[name]]:
    if nam = "Nidoranº":
        nam = "Nidoran"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-13a3dd0892a5> in <module>()
# ----> 1 incidence_count = police_data_df.groupby([['X','Y']]).count()
#       2 incidence_count
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    4414         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    4415                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 4416                        **kwargs)
#    4417
#    4418     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in groupby(obj, by, **kwds)
#    1697         raise TypeError('invalid type: %s' % type(obj))
#    1698
# -> 1699     return klass(obj, by, **kwds)
#    1700
#    1701
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, **kwargs)
#     390                                                     level=level,
#     391                                                     sort=sort,
# --> 392                                                     mutated=self.mutated)
#     393
#     394         self.obj = obj
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in _get_grouper(obj, key, axis, level, sort, mutated)
#    2709                         sort=sort,
#    2710                         in_axis=in_axis) \
# -> 2711             if not isinstance(gpr, Grouping) else gpr
#    2712
#    2713         groupings.append(ping)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in __init__(self, index, grouper, obj, name, level, sort, in_axis)
#    2418         self.name = name
#    2419         self.level = level
# -> 2420         self.grouper = _convert_grouper(index, grouper)
#    2421         self.index = index
#    2422         self.sort = sort
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby.py in _convert_grouper(axis, grouper)
#    2737     elif isinstance(grouper, (list, Series, Index, np.ndarray)):
#    2738         if len(grouper) != len(axis):
# -> 2739             raise ValueError('Grouper and axis must be same length')
#    2740         return grouper
#    2741     else:
#
# ValueError: Grouper and axis must be same length

# %%
police_data_df = pd.read_csv("Resources/police-department-incidents.csv")
police_data_df = police_data_df[["IncidntNum", "Descript", "PdDistrict", "Resolution", "X", "Y"]]
police_data_df.head()
# Out:
#    IncidntNum                                           Descript PdDistrict  \
# 0    50436712                                            BATTERY    MISSION
# 1   130366639                    AGGRAVATED ASSAULT WITH A KNIFE  INGLESIDE
# 2   141024103  CHILD, INFLICTING INJURY RESULTING IN TRAUMATI...    MISSION
# 3    51142198                               THREATS AGAINST LIFE    CENTRAL
# 4   140684794                                            BATTERY    BAYVIEW
#
#        Resolution           X          Y
# 0            NONE -122.435003  37.760888
# 1  ARREST, BOOKED -122.444707  37.724931
# 2  ARREST, BOOKED -122.407102  37.762558
# 3  ARREST, BOOKED -122.403847  37.789828
# 4            NONE -122.402554  37.765419

# %%
# Aggregating data based on the lat and long

# %% [markdown]
# ----
#
# ### Transform pokemon DataFrame

# %%
new_poke_df = pokemon_data_df[[\
    's2_token','name','lat','lng']].copy()
new_poke_df.head()
# Out:
#       s2_token     name        lat         lng
# 0  8085808cc6d   Weedle  37.793592 -122.408721
# 1  8085808b51d   Pidgey  37.794746 -122.406420
# 2  8085808b271    Zubat  37.794999 -122.404384
# 3  808580f3587   Pidgey  37.795644 -122.407128
# 4  808580f4b1d  Poliwag  37.795592 -122.406331

# %%
#change column names for new_poke_df
'''new_poke_df.rename(columns={'s2_token':'id',
    'num':''},
    'name':'',
    'encounter_ms':'',
    'disppear_ms'},
    inplace=True)'''
new_poke_df.drop_duplicates("s2_token", inplace=True)
new_poke_df.set_index("s2_token", inplace=True)
new_poke_df.head()
# Out:
#                 name        lat         lng
# s2_token
# 8085808cc6d   Weedle  37.793592 -122.408721
# 8085808b51d   Pidgey  37.794746 -122.406420
# 8085808b271    Zubat  37.794999 -122.404384
# 808580f3587   Pidgey  37.795644 -122.407128
# 808580f4b1d  Poliwag  37.795592 -122.406331

# %% [markdown]
# ### Transform police DataFrame

# %%
police_data_df = police__df[[\
    "IncidntNum", "Descript", "PdDistrict", "Resolution", "X", "Y"]].copy()
police_data_df.head()
# Out:
#    IncidntNum                                           Descript PdDistrict  \
# 0    50436712                                            BATTERY    MISSION
# 1   130366639                    AGGRAVATED ASSAULT WITH A KNIFE  INGLESIDE
# 2   141024103  CHILD, INFLICTING INJURY RESULTING IN TRAUMATI...    MISSION
# 3    51142198                               THREATS AGAINST LIFE    CENTRAL
# 4   140684794                                            BATTERY    BAYVIEW
#
#        Resolution           X          Y
# 0            NONE -122.435003  37.760888
# 1  ARREST, BOOKED -122.444707  37.724931
# 2  ARREST, BOOKED -122.407102  37.762558
# 3  ARREST, BOOKED -122.403847  37.789828
# 4            NONE -122.402554  37.765419

# %%
#change column names for new_police_df
police_data_df.rename(columns={'IncidntNum':'inc_num',
    'Descript':'descr',
    'PdDistrict':'district',
    'Resolution':'resolution',
    'X':'lng',
    'Y':'lat'}, 
    inplace=True)
police_data_df.set_index("inc_num", inplace=True)
police_data_df.head()
# Out:
#                                                        descr   district  \
# inc_num
# 50436712                                             BATTERY    MISSION
# 130366639                    AGGRAVATED ASSAULT WITH A KNIFE  INGLESIDE
# 141024103  CHILD, INFLICTING INJURY RESULTING IN TRAUMATI...    MISSION
# 51142198                                THREATS AGAINST LIFE    CENTRAL
# 140684794                                            BATTERY    BAYVIEW
#
#                resolution         lng        lat
# inc_num
# 50436712             NONE -122.435003  37.760888
# 130366639  ARREST, BOOKED -122.444707  37.724931
# 141024103  ARREST, BOOKED -122.407102  37.762558
# 51142198   ARREST, BOOKED -122.403847  37.789828
# 140684794            NONE -122.402554  37.765419

# %% [markdown]
# ### Create database connection

# %%
#rds_connection_string = "<inser user name>:<insert password>@127.0.0.1/customer_db"
#engine = create_engine(f'mysql://{rds_connection_string}')
engine = create_engine(f'mysql://root:Redondo0505@localhost:3306/pokemon_police_db')

# %%
# Confirm tables
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1121             wait = use_overflow and self._overflow >= self._max_overflow
# -> 1122             return self._pool.get(wait, self._timeout)
#    1123         except sqla_queue.Empty:
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/util/queue.py in get(self, block, timeout)
#     144                 if self._empty():
# --> 145                     raise Empty
#     146             elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2146         try:
# -> 2147             return fn()
#    2148         except dialect.dbapi.Error as e:
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/pool.py in connect(self)
#     386         if not self._use_threadlocal:
# --> 387             return _ConnectionFairy._checkout(self)
#     388
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     765         if not fairy:
# --> 766             fairy = _ConnectionRecord.checkout(pool)
#     767
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     515     def checkout(cls, pool):
# --> 516         rec = pool._do_get()
#     517         try:
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1137                     with util.safe_reraise():
# -> 1138                         self._dec_overflow()
#    1139             else:
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1134                 try:
# -> 1135                     return self._create_connection()
#    1136                 except:
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/pool.py in _create_connection(self)
#     332
# --> 333         return _ConnectionRecord(self)
#     334
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/pool.py in __init__(self, pool, connect)
#     460         if connect:
# --> 461             self.__connect(first_connect_check=True)
#     462         self.finalize_callback = deque()
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/pool.py in __connect(self, first_connect_check)
#     650             self.starttime = time.time()
# --> 651             connection = pool._invoke_creator(self)
#     652             pool.logger.debug("Created new connection %r", connection)
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     104                             return connection
# --> 105                 return dialect.connect(*cargs, **cparams)
#     106
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     392     def connect(self, *cargs, **cparams):
# --> 393         return self.dbapi.connect(*cargs, **cparams)
#     394
#
# ~/anaconda3/lib/python3.6/site-packages/pymysql/__init__.py in Connect(*args, **kwargs)
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#
# ~/anaconda3/lib/python3.6/site-packages/pymysql/connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     326         else:
# --> 327             self.connect()
#     328
#
# ~/anaconda3/lib/python3.6/site-packages/pymysql/connections.py in connect(self, sock)
#     597             self._get_server_information()
# --> 598             self._request_authentication()
#     599
#
# ~/anaconda3/lib/python3.6/site-packages/pymysql/connections.py in _request_authentication(self)
#     861             if self.server_capabilities & CLIENT.PLUGIN_AUTH and plugin_name is not None:
# --> 862                 auth_packet = self._process_auth(plugin_name, auth_packet)
#     863             else:
#
# ~/anaconda3/lib/python3.6/site-packages/pymysql/connections.py in _process_auth(self, plugin_name, auth_packet)
#     932         self.write_packet(data)
# --> 933         pkt = self._read_packet()
#     934         pkt.check_error()
#
# ~/anaconda3/lib/python3.6/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     682         packet = packet_type(buff, self.encoding)
# --> 683         packet.check_error()
#     684         return packet
#
# ~/anaconda3/lib/python3.6/site-packages/pymysql/protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# ~/anaconda3/lib/python3.6/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# OperationalError: (1045, "Access denied for user 'root'@'localhost' (using password: YES)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-18-390e170ef6b2> in <module>()
#       1 # Confirm tables
# ----> 2 engine.table_names()
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in table_names(self, schema, connection)
#    2123         """
#    2124
# -> 2125         with self._optional_conn_ctx_manager(connection) as conn:
#    2126             if not schema:
#    2127                 schema = self.dialect.default_schema_name
#
# ~/anaconda3/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _optional_conn_ctx_manager(self, connection)
#    1919     def _optional_conn_ctx_manager(self, connection=None):
#    1920         if connection is None:
# -> 1921             with self.contextual_connect() as conn:
#    1922                 yield conn
#    1923         else:
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in contextual_connect(self, close_with_result, **kwargs)
#    2110         return self._connection_cls(
#    2111             self,
# -> 2112             self._wrap_pool_connect(self.pool.connect, None),
#    2113             close_with_result=close_with_result,
#    2114             **kwargs)
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2149             if connection is None:
#    2150                 Connection._handle_dbapi_exception_noconnection(
# -> 2151                     e, dialect, self)
#    2152             else:
#    2153                 util.reraise(*sys.exc_info())
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1463             util.raise_from_cause(
#    1464                 sqlalchemy_exception,
# -> 1465                 exc_info
#    1466             )
#    1467         else:
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2145         dialect = self.dialect
#    2146         try:
# -> 2147             return fn()
#    2148         except dialect.dbapi.Error as e:
#    2149             if connection is None:
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/pool.py in connect(self)
#     385         """
#     386         if not self._use_threadlocal:
# --> 387             return _ConnectionFairy._checkout(self)
#     388
#     389         try:
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     764     def _checkout(cls, pool, threadconns=None, fairy=None):
#     765         if not fairy:
# --> 766             fairy = _ConnectionRecord.checkout(pool)
#     767
#     768             fairy._pool = pool
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     514     @classmethod
#     515     def checkout(cls, pool):
# --> 516         rec = pool._do_get()
#     517         try:
#     518             dbapi_connection = rec.get_connection()
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1136                 except:
#    1137                     with util.safe_reraise():
# -> 1138                         self._dec_overflow()
#    1139             else:
#    1140                 return self._do_get()
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      64             self._exc_info = None   # remove potential circular references
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#      68             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     185         if value.__traceback__ is not tb:
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#     189 else:
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1133             if self._inc_overflow():
#    1134                 try:
# -> 1135                     return self._create_connection()
#    1136                 except:
#    1137                     with util.safe_reraise():
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/pool.py in _create_connection(self)
#     331         """Called by subclasses to create a new ConnectionRecord."""
#     332
# --> 333         return _ConnectionRecord(self)
#     334
#     335     def _invalidate(self, connection, exception=None):
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/pool.py in __init__(self, pool, connect)
#     459         self.__pool = pool
#     460         if connect:
# --> 461             self.__connect(first_connect_check=True)
#     462         self.finalize_callback = deque()
#     463
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/pool.py in __connect(self, first_connect_check)
#     649         try:
#     650             self.starttime = time.time()
# --> 651             connection = pool._invoke_creator(self)
#     652             pool.logger.debug("Created new connection %r", connection)
#     653             self.connection = connection
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     103                         if connection is not None:
#     104                             return connection
# --> 105                 return dialect.connect(*cargs, **cparams)
#     106
#     107             creator = pop_kwarg('creator', connect)
#
# ~/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     391
#     392     def connect(self, *cargs, **cparams):
# --> 393         return self.dbapi.connect(*cargs, **cparams)
#     394
#     395     def create_connect_args(self, url):
#
# ~/anaconda3/lib/python3.6/site-packages/pymysql/__init__.py in Connect(*args, **kwargs)
#      92     """
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#      96 from . import connections as _orig_conn
#
# ~/anaconda3/lib/python3.6/site-packages/pymysql/connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     325             self._sock = None
#     326         else:
# --> 327             self.connect()
#     328
#     329     def _create_ssl_ctx(self, sslp):
#
# ~/anaconda3/lib/python3.6/site-packages/pymysql/connections.py in connect(self, sock)
#     596
#     597             self._get_server_information()
# --> 598             self._request_authentication()
#     599
#     600             if self.sql_mode is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/pymysql/connections.py in _request_authentication(self)
#     860             plugin_name = auth_packet.read_string()
#     861             if self.server_capabilities & CLIENT.PLUGIN_AUTH and plugin_name is not None:
# --> 862                 auth_packet = self._process_auth(plugin_name, auth_packet)
#     863             else:
#     864                 # send legacy handshake
#
# ~/anaconda3/lib/python3.6/site-packages/pymysql/connections.py in _process_auth(self, plugin_name, auth_packet)
#     931
#     932         self.write_packet(data)
# --> 933         pkt = self._read_packet()
#     934         pkt.check_error()
#     935         return pkt
#
# ~/anaconda3/lib/python3.6/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     681
#     682         packet = packet_type(buff, self.encoding)
# --> 683         packet.check_error()
#     684         return packet
#     685
#
# ~/anaconda3/lib/python3.6/site-packages/pymysql/protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# ~/anaconda3/lib/python3.6/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1045, "Access denied for user 'root'@'localhost' (using password: YES)")

# %% [markdown]
# ### Load DataFrames into database

# %%
new_poke_df.to_sql(name='pokemon', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     506     def do_execute(self, cursor, statement, parameters, context=None):
# --> 507         cursor.execute(statement, parameters)
#     508
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     515         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 516         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     517         return self._affected_rows
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     726             result = MySQLResult(self)
# --> 727             result.read()
#     728         self._result = result
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1065         try:
# -> 1066             first_packet = self.connection._read_packet()
#    1067
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     682         packet = packet_type(buff, self.encoding)
# --> 683         packet.check_error()
#     684         return packet
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# DataError: (1265, "Data truncated for column 's2_token' at row 1")
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# <ipython-input-12-5ffa0ca3d7ed> in <module>()
# ----> 1 new_poke_df.to_sql(name='pokemon', con=engine, if_exists='append', index=True)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2125         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2126                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2127                    dtype=dtype)
#    2128
#    2129     def to_pickle(self, path, compression='infer',
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     449                       index_label=index_label, schema=schema,
# --> 450                       chunksize=chunksize, dtype=dtype)
#     451
#     452
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1147                          schema=schema, dtype=dtype)
#    1148         table.create()
# -> 1149         table.insert(chunksize)
#    1150         if (not name.isdigit() and not name.islower()):
#    1151             # check for potentially case sensitivity issues (GH7815)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize)
#     661
#     662                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 663                 self._execute_insert(conn, keys, chunk_iter)
#     664
#     665     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     636         """Insert data into this table with database connection"""
#     637         data = [{k: v for k, v in zip(keys, row)} for row in data_iter]
# --> 638         conn.execute(*self.insert_statement(data, conn))
#     639
#     640     def insert(self, chunksize=None):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object, *multiparams, **params)
#     946             raise exc.ObjectNotExecutableError(object)
#     947         else:
# --> 948             return meth(self, multiparams, params)
#     949
#     950     def _execute_function(self, func, multiparams, params):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     267     def _execute_on_connection(self, connection, multiparams, params):
#     268         if self.supports_execution:
# --> 269             return connection._execute_clauseelement(self, multiparams, params)
#     270         else:
#     271             raise exc.ObjectNotExecutableError(self)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1058             compiled_sql,
#    1059             distilled_params,
# -> 1060             compiled_sql, distilled_params
#    1061         )
#    1062         if self._has_events or self.engine._has_events:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1411                 util.raise_from_cause(
#    1412                     sqlalchemy_exception,
# -> 1413                     exc_info
#    1414                 )
#    1415             else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1191                         statement,
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#    1195             self._handle_dbapi_exception(
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     505
#     506     def do_execute(self, cursor, statement, parameters, context=None):
# --> 507         cursor.execute(statement, parameters)
#     508
#     509     def do_execute_no_params(self, cursor, statement, context=None):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     514                 sql = sql.encode(self.encoding, 'surrogateescape')
#     515         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 516         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     517         return self._affected_rows
#     518
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     725         else:
#     726             result = MySQLResult(self)
# --> 727             result.read()
#     728         self._result = result
#     729         if result.server_status is not None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1064     def read(self):
#    1065         try:
# -> 1066             first_packet = self.connection._read_packet()
#    1067
#    1068             if first_packet.is_ok_packet():
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     681
#     682         packet = packet_type(buff, self.encoding)
# --> 683         packet.check_error()
#     684         return packet
#     685
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# DataError: (pymysql.err.DataError) (1265, "Data truncated for column 's2_token' at row 1") [SQL: 'INSERT INTO pokemon (s2_id, s2_token, num, name, lat, lng, encounter_ms, disppear_ms) VALUES (%(s2_id_m0)s, %(s2_token_m0)s, %(num_m0)s, %(name_m0)s, %(lat_m0)s, %(lng_m0)s, %(encounter_ms_m0)s, %(disppear_ms_m0)s), (%(s2_id_m1)s, %(s2_token_m1)s, %(num_m1)s, %(name_m1)s, %(lat_m1)s, %(lng_m1)s, %(encounter_ms_m1)s, %(disppear_ms_m1)s), (%(s2_id_m2)s, %(s2_token_m2)s, %(num_m2)s, %(name_m2)s, %(lat_m2)s, %(lng_m2)s, %(encounter_ms_m2)s, %(disppear_ms_m2)s), (%(s2_id_m3)s, %(s2_token_m3)s, %(num_m3)s, %(name_m3)s, %(lat_m3)s, %(lng_m3)s, %(encounter_ms_m3)s, %(disppear_ms_m3)s), (%(s2_id_m4)s, %(s2_token_m4)s, %(num_m4)s, %(name_m4)s, %(lat_m4)s, %(lng_m4)s, %(encounter_ms_m4)s, %(disppear_ms_m4)s), (%(s2_id_m5)s, %(s2_token_m5)s, %(num_m5)s, %(name_m5)s, %(lat_m5)s, %(lng_m5)s, %(encounter_ms_m5)s, %(disppear_ms_m5)s), (%(s2_id_m6)s, %(s2_token_m6)s, %(num_m6)s, %(name_m6)s, %(lat_m6)s, %(lng_m6)s, %(encounter_ms_m6)s, %(disppear_ms_m6)s), (%(s2_id_m7)s, %(s2_token_m7)s, %(num_m7)s, %(name_m7)s, %(lat_m7)s, %(lng_m7)s, %(encounter_ms_m7)s, %(disppear_ms_m7)s), (%(s2_id_m8)s, %(s2_token_m8)s, %(num_m8)s, %(name_m8)s, %(lat_m8)s, %(lng_m8)s, %(encounter_ms_m8)s, %(disppear_ms_m8)s), (%(s2_id_m9)s, %(s2_token_m9)s, %(num_m9)s, %(name_m9)s, %(lat_m9)s, %(lng_m9)s, %(encounter_ms_m9)s, %(disppear_ms_m9)s), (%(s2_id_m10)s, %(s2_token_m10)s, %(num_m10)s, %(name_m10)s, %(lat_m10)s, %(lng_m10)s, %(encounter_ms_m10)s, %(disppear_ms_m10)s), (%(s2_id_m11)s, %(s2_token_m11)s, %(num_m11)s, %(name_m11)s, %(lat_m11)s, %(lng_m11)s, %(encounter_ms_m11)s, %(disppear_ms_m11)s), (%(s2_id_m12)s, %(s2_token_m12)s, %(num_m12)s, %(name_m12)s, %(lat_m12)s, %(lng_m12)s, %(encounter_ms_m12)s, %(disppear_ms_m12)s), (%(s2_id_m13)s, %(s2_token_m13)s, %(num_m13)s, %(name_m13)s, %(lat_m13)s, %(lng_m13)s, %(encounter_ms_m13)s, %(disppear_ms_m13)s), (%(s2_id_m14)s, %(s2_token_m14)s, %(num_m14)s, %(name_m14)s, %(lat_m14)s, %(lng_m14)s, %(encounter_ms_m14)s, %(disppear_ms_m14)s), (%(s2_id_m15)s, %(s2_token_m15)s, %(num_m15)s, %(name_m15)s, %(lat_m15)s, %(lng_m15)s, %(encounter_ms_m15)s, %(disppear_ms_m15)s), (%(s2_id_m16)s, %(s2_token_m16)s, %(num_m16)s, %(name_m16)s, %(lat_m16)s, %(lng_m16)s, %(encounter_ms_m16)s, %(disppear_ms_m16)s), (%(s2_id_m17)s, %(s2_token_m17)s, %(num_m17)s, %(name_m17)s, %(lat_m17)s, %(lng_m17)s, %(encounter_ms_m17)s, %(disppear_ms_m17)s), (%(s2_id_m18)s, %(s2_token_m18)s, %(num_m18)s, %(name_m18)s, %(lat_m18)s, %(lng_m18)s, %(encounter_ms_m18)s, %(disppear_ms_m18)s), (%(s2_id_m19)s, %(s2_token_m19)s, %(num_m19)s, %(name_m19)s, %(lat_m19)s, %(lng_m19)s, %(encounter_ms_m19)s, %(disppear_ms_m19)s), (%(s2_id_m20)s, %(s2_token_m20)s, %(num_m20)s, %(name_m20)s, %(lat_m20)s, %(lng_m20)s, %(encounter_ms_m20)s, %(disppear_ms_m20)s), (%(s2_id_m21)s, %(s2_token_m21)s, %(num_m21)s, %(name_m21)s, %(lat_m21)s, %(lng_m21)s, %(encounter_ms_m21)s, %(disppear_ms_m21)s), (%(s2_id_m22)s, %(s2_token_m22)s, %(num_m22)s, %(name_m22)s, %(lat_m22)s, %(lng_m22)s, %(encounter_ms_m22)s, %(disppear_ms_m22)s), (%(s2_id_m23)s, %(s2_token_m23)s, %(num_m23)s, %(name_m23)s, %(lat_m23)s, %(lng_m23)s, %(encounter_ms_m23)s, %(disppear_ms_m23)s), (%(s2_id_m24)s, %(s2_token_m24)s, %(num_m24)s, %(name_m24)s, %(lat_m24)s, %(lng_m24)s, %(encounter_ms_m24)s, %(disppear_ms_m24)s), (%(s2_id_m25)s, %(s2_token_m25)s, %(num_m25)s, %(name_m25)s, %(lat_m25)s, %(lng_m25)s, %(encounter_ms_m25)s, %(disppear_ms_m25)s), (%(s2_id_m26)s, %(s2_token_m26)s, %(num_m26)s, %(name_m26)s, %(lat_m26)s, %(lng_m26)s, %(encounter_ms_m26)s, %(disppear_ms_m26)s), (%(s2_id_m27)s, %(s2_token_m27)s, %(num_m27)s, %(name_m27)s, %(lat_m27)s, %(lng_m27)s, %(encounter_ms_m27)s, %(disppear_ms_m27)s), (%(s2_id_m28)s, %(s2_token_m28)s, %(num_m28)s, %(name_m28)s, %(lat_m28)s, %(lng_m28)s, %(encounter_ms_m28)s, %(disppear_ms_m28)s), (%(s2_id_m29)s, %(s2_token_m29)s, %(num_m29)s, %(name_m29)s, %(lat_m29)s, %(lng_m29)s, %(e ...

# %%
new_police_df.to_sql(name='police', con=engine, if_exists='append', index=True)

# %%
pd.read_sql_query('select * from premise', con=engine).head()
# Out:
#         id                        premise_name  county_id
# 0  1300091  TWO THOUSAND FIFTEEN ARTISANAL LLC          2
# 1  1307023                JA EXPRESS FOOD CORP          8
# 2  1307145                  TRINITA PARETE LLC          2
# 3  1307243            CRESCENT ST PIZZERIA INC          1
# 4  1307463       LA REGIA DELI RESTAURANT CORP         10

# %%
pd.read_sql_query('select * from county', con=engine).head()
# Out:
#    id  county_name  license_count  county_id
# 0   0       ALBANY             77          5
# 1   1     ALLEGANY              4         59
# 2   2        BRONX            104          0
# 3   3       BROOME             14         35
# 4   4  CATTARAUGUS              9         41
